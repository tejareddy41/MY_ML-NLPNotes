# %% [markdown]
# #Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# %cd /content/gdrive/MyDrive/..........

# %% [markdown]
# #Load the Dataset

# %%
import pandas as pd
df = pd.read_csv('bbc_sports.csv')
df.head()

# %% [markdown]
# Target class names

# %%
classes =['athletics', 'cricket', 'football', 'rugby', 'tennis']

# %% [markdown]
# #Preprocess Data

# %%
# %run preprocess.ipynb #the colab that has preprocessing functions

# %% [markdown]
# #Vectorise Data

# %% [markdown]
# #ML Alog 1

# %%
fit(X,y)
score()
predict(newX)

# %% [markdown]
# #ML Algo 2

# %% [markdown]
# ML Algo

# %% [markdown]
# #Test with Sample News

# %% [markdown]
# #Compare best classifier
